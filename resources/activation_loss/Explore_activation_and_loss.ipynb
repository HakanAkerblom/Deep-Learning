# %% [markdown]
# # Activation and Loss Function Exploration Exercise
#
# ## Background
# This exercise aims to explore the effects of different activation and loss functions on a neural network's learning and performance. You will modify a simple neural network in TensorFlow to experiment with these functions.
#
# ## Activation Functions
# Common activation functions include:
#
# * Sigmoid
# * ReLU (Rectified Linear Unit)
# * Tanh (Hyperbolic Tangent)
#
# ## Loss Functions
# Some standard loss functions are:
#
# * Mean Squared Error (MSE) - typically used for regression tasks
# * Binary Cross-Entropy - used for binary classification
# * Categorical Cross-Entropy - used for multi-class classification

# %% [markdown]
# # Setup
# First, let's import TensorFlow and other necessary libraries. Run the cell below to import them.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Dataset Preparation
# We'll use a synthetic dataset for binary classification. The 'make_moons' function from scikit-learn generates a two-moon dataset, which is ideal for this experiment.

# %%
# Generate synthetic data
X, y = make_moons(n_samples=1000, noise=0.2, random_state=42)

# Splitting the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Visualize the dataset
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.RdBu)
plt.title("Training Data")
plt.show()

# %% [markdown]
# ## Model Building
# Now, let's define a function to create a simple neural network model. You will modify this function later to experiment with different activation and loss functions.

# %%
def build_model(activation_function='relu', loss_function='binary_crossentropy'):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(10, activation=activation_function, input_shape=(2,)),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss=loss_function, metrics=['accuracy'])
    return model

# %% [markdown]
# # Training and evaluating the model
# Let's train the model and see how well it solves the problem.

# %%
# Function to train, evaluate, and visualize model predictions along with ground truth
def train_and_evaluate_model(model, epochs=100):
    history = model.fit(X_train, y_train, epochs=epochs, verbose=0, validation_split=0.2)
    
    # Evaluating the model on the test set
    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    
    # Plotting training history
    plt.figure(figsize=(18, 5))

    plt.subplot(1, 3, 1)
    plt.plot(history.history['accuracy'], label='Accuracy (training data)')
    plt.plot(history.history['val_accuracy'], label='Accuracy (validation data)')
    plt.title('Training and Validation Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend()

    # Predicting on test data
    predictions = model.predict(X_test) > 0.5

    # Plotting model predictions
    plt.subplot(1, 3, 2)
    plt.scatter(X_test[:, 0], X_test[:, 1], c=predictions[:, 0], cmap=plt.cm.coolwarm)
    plt.title('Model Predictions on Test Data')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')

    # Plotting ground truth
    plt.subplot(1, 3, 3)
    plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=plt.cm.coolwarm)
    plt.title('Ground Truth for Test Data')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')

    plt.show()

    print(f"Test Loss: {test_loss:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")

# Example of using the function with a specific activation and loss function
model = build_model(activation_function='relu', loss_function='binary_crossentropy')
train_and_evaluate_model(model, epochs=100)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\IPython\core\interactiveshell.py", line 3548, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\HåkanÅkerblom\AppData\Local\Temp\ipykernel_22596\1277622935.py", line 44, in <module>
#     train_and_evaluate_model(model, epochs=100)
#   File "C:\Users\HåkanÅkerblom\AppData\Local\Temp\ipykernel_22596\1277622935.py", line 4, in train_and_evaluate_model
#     history = model.fit(X_train, y_train, epochs=epochs, verbose=0, validation_split=0.2, shuffle=True, random_seed=42)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\keras\src\utils\traceback_utils.py", line 67, in error_handler
#     filtered_tb = _process_traceback_frames(e.__traceback__)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: Model.fit() got an unexpected keyword argument 'random_seed'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\IPython\core\interactiveshell.py", line 2142, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\IPython\core\ultratb.py", line 1063, in format_exception_as_a_whole
#     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\IPython\core\ultratb.py", line 1160, in get_records
#     res = list(stack_data.FrameInfo.stack_data(etb, options=options))[tb_offset:]
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\stack_data\core.py", line 597, in stack_data
#     yield from collapse_repeated(
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\stack_data\utils.py", line 83, in collapse_repeated
#     yield from map(mapper, original_group)
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\stack_data\core.py", line 587, in mapper
#     return cls(f, options)
#            ^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\stack_data\core.py", line 551, in __init__
#     self.executing = Source.executing(frame_or_tb)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\executing\executing.py", line 283, in executing
#     assert_(new_stmts <= stmts)
#   File "c:\Users\HåkanÅkerblom\.virtualenvs\Deep-Learning-Aabymfw1\Lib\site-packages\executing\executing.py", line 80, in assert_
#     raise AssertionError(str(message))
# AssertionError

# %% [markdown]
# # Experimentation
# ## Task 1: Activation Functions
# 1. Experiment with different activation functions in the hidden layer. Replace activation_function in build_model with 'sigmoid', 'relu', and 'tanh'.
# 2. Train the model for each activation function and evaluate its performance on the test set.
# 3. Record your observations.
# ## Task 2: Loss Functions
# 1. Now, experiment with different loss functions. For binary classification, try 'binary_crossentropy' and 'mean_squared_error'.
# 2. Train and evaluate the model for each loss function.
# 3. Record your observations.
#
# # Analysis and Questions
# After completing the tasks, answer the following questions:
#
# 1. How did different activation functions affect the model's performance?
# 2. How did different loss functions impact the learning process and accuracy?
# 3. Which combination of activation and loss function provided the best results for this task?
#
# # Conclusion
# Summarize your findings and discuss why certain combinations might work better than others for this specific problem.
